# %%
import pandas as pd 
import numpy as np

# %%
student_score_dict = [
{'name':'김철수','kor':90, 'eng':'', 'math':0},
{'name':'박제동','kor':70, 'eng':50, 'math':100},
{'name':'홍길동','kor':80, 'eng':None, 'math':''},
{'name':'김철수','kor':90, 'eng':20, 'math':70},
{'name':'장길산','kor':None, 'eng':120, 'math':None},
{'name':'홍길동','kor':80, 'eng':None, 'math':0},
{'name':'정진수','kor':90, 'eng':0, 'math':80},
{'name':'오금순','kor':50, 'eng':70, 'math':None},
{'name':'정만득','kor':None, 'eng':None, 'math':None},
]
df_data = pd.DataFrame(student_score_dict)

# %%
df_data.describe(include='all')
# Out:
#        name        kor    eng  math
# count     9   7.000000    6.0   6.0
# unique    7        NaN    6.0   5.0
# top     홍길동        NaN  120.0   0.0
# freq      2        NaN    1.0   2.0
# mean    NaN  78.571429    NaN   NaN
# std     NaN  14.638501    NaN   NaN
# min     NaN  50.000000    NaN   NaN
# 25%     NaN  75.000000    NaN   NaN
# 50%     NaN  80.000000    NaN   NaN
# 75%     NaN  90.000000    NaN   NaN
# max     NaN  90.000000    NaN   NaN

# %%
#column approach method

df_data['name'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# Name: name, dtype: bool

# %%
#drop duplicate rows

df_data['name'].drop_duplicates(keep = 'first')
# Out:
# 0    김철수
# 1    박제동
# 2    홍길동
# 4    장길산
# 6    정진수
# 7    오금순
# 8    정만득
# Name: name, dtype: object

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    9 non-null      object
#  1   kor     7 non-null      float64
#  2   eng     6 non-null      object
#  3   math    6 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 416.0+ bytes

# %%
df_data.isnull().sum()
# Out:
# name    0
# kor     2
# eng     3
# math    3
# dtype: int64

# %%
df_data['name'].value_counts()
# Out:
# 홍길동    2
# 김철수    2
# 장길산    1
# 오금순    1
# 정만득    1
# 박제동    1
# 정진수    1
# Name: name, dtype: int64

# %%
#Fill column with something

df_data['kor'] = df_data['kor'].fillna(df_data['kor'].mean())

df_data
# Out:
#   name        kor   eng  math
# 0  김철수  90.000000           0
# 1  박제동  70.000000    50   100
# 2  홍길동  80.000000  None
# 3  김철수  90.000000    20    70
# 4  장길산  78.571429   120  None
# 5  홍길동  80.000000  None     0
# 6  정진수  90.000000     0    80
# 7  오금순  50.000000    70  None
# 8  정만득  78.571429  None  None

# %%
#data type

df_data.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-be668e186775> in <module>()
#       1
# ----> 2 df_data.dtype()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
#replace  '' to nan for using FILLNA

df_data['eng'] = df_data['eng'].replace({'':np.nan})
df_data
# Out:
#   name        kor    eng  math
# 0  김철수  90.000000    NaN     0
# 1  박제동  70.000000   50.0   100
# 2  홍길동  80.000000    NaN
# 3  김철수  90.000000   20.0    70
# 4  장길산  78.571429  120.0  None
# 5  홍길동  80.000000    NaN     0
# 6  정진수  90.000000    0.0    80
# 7  오금순  50.000000   70.0  None
# 8  정만득  78.571429    NaN  None

# %%
df_data['eng'] = df_data['eng'].fillna(df_data['eng'].median())
df_data
# Out:
#   name        kor    eng  math
# 0  김철수  90.000000   50.0     0
# 1  박제동  70.000000   50.0   100
# 2  홍길동  80.000000   50.0
# 3  김철수  90.000000   20.0    70
# 4  장길산  78.571429  120.0  None
# 5  홍길동  80.000000   50.0     0
# 6  정진수  90.000000    0.0    80
# 7  오금순  50.000000   70.0  None
# 8  정만득  78.571429   50.0  None

# %%
df_data['math'] = df_data['math'].replace({'':np.nan})
df_data['math'] = df_data['math'].fillna(df_data['math'].median())

# %%
df_data
# Out:
#   name        kor    eng  math
# 0  김철수  90.000000   50.0     0
# 1  박제동  70.000000   50.0   100
# 2  홍길동  80.000000   50.0
# 3  김철수  90.000000   20.0    70
# 4  장길산  78.571429  120.0  None
# 5  홍길동  80.000000   50.0     0
# 6  정진수  90.000000    0.0    80
# 7  오금순  50.000000   70.0  None
# 8  정만득  78.571429   50.0  None
