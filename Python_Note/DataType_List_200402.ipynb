# %%
cast = ['cleese', 'palin', 34.52, 'idle', 'cleese']

# %%
len(cast)
# Out:
# 5

# %%
print(cast[2], cast[-2], cast[1:])
# Out:
# 34.52 idle ['palin', 34.52, 'idle', 'cleese']

# %%
cast.append("Gillian")
cast
# Out:
# ['cleese', 'palin', 34.52, 'idle', 'cleese', 'Gillian']

# %%
cast.count('cleese')      #해당 객체가 몇 번 등장하는 지 세어 줌
# Out:
# 2

# %%
cast.extend(['idle','Gilliam'])     #객체를 연속적으로 덧붙임

# %%
cast
# Out:
# ['cleese', 'palin', 34.52, 'idle', 'cleese', 'Gillian', 'idle', 'Gilliam']

# %%
cast.pop()      #마지막 객체를 지움
cast
# Out:
# ['cleese', 'palin', 34.52, 'idle', 'cleese', 'Gillian', 'idle']

# %%
cast.insert(3,"NAYA")     #원하는 인덱스에 객체를 추가
cast
# Out:
# ['cleese', 'palin', 34.52, 'NAYA', 'idle', 'cleese', 'Gillian', 'idle']

# %%
cast.remove(34.52)      #객체를 리스트에서 제거
cast
# Out:
# ['cleese', 'palin', 'NAYA', 'idle', 'cleese', 'Gillian', 'idle']

# %%
del cast[1]     #원하는 인덱스의 값을 삭제
cast
# Out:
# ['cleese', 'NAYA', 'idle', 'cleese', 'Gillian', 'idle']
# ERROR! Session/line number was not unique in database. History logging moved to new session 60

# %%
cast.reverse()
cast
# Out:
# ['cleese', 'NAYA', 'idle', 'cleese', 'Gillian', 'idle']

# %%
isinstance(cast, list)      #변수가 해당 형태의 타입인지 확인하는 함수
# Out:
# True

# %%
myclass = [
     {'num' : '1', 'name' : '박지선', 'kor' : 90, 'eng' :80, 'math' : 85, 'total' : 0, 'avg' : 0.0, 'order' : 0},
     {'num' : '2', 'name' : '윤이나', 'kor' : 90, 'eng' :85, 'math' : 90, 'total' : 0, 'avg' : 0.0, 'order' : 0},
     {'num' : '3', 'name' : '송은이', 'kor' : 80, 'eng' :80, 'math' : 80, 'total' : 0, 'avg' : 0.0, 'order' : 0}
]
myclass

# %%
myclass.reverse()     #행의 순서를 반전시키는 함수

# %%
myclass
# Out:
# [{'avg': 0.0,
#   'eng': 80,
#   'kor': 80,
#   'math': 80,
#   'name': '송은이',
#   'num': '3',
#   'order': 0,
#   'total': 0},
#  {'avg': 0.0,
#   'eng': 85,
#   'kor': 90,
#   'math': 90,
#   'name': '윤이나',
#   'num': '2',
#   'order': 0,
#   'total': 0},
#  {'avg': 0.0,
#   'eng': 80,
#   'kor': 90,
#   'math': 85,
#   'name': '박지선',
#   'num': '1',
#   'order': 0,
#   'total': 0}]
