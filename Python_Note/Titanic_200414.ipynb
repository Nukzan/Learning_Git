# %% [markdown]
# *** Each column description ***
#
# - survival : Survival (0 = No; 1 = Yes)
# - class : Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - name : Name
# - sex : Sex
# - age : Age
# - sibsp : Number of Siblings/Spouses Aboard
# - parch : Number of Parents/Children Aboard
# - ticket : Ticket Number
# - fare : Passenger Fare
# - cabin : Cabin
# - embarked : Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - boat : Lifeboat (if survived)
# - body : Body number (if did not survive and body was recovered)

# %%
import numpy as np
import pandas as pd
import os

# !pip install wget
import wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=b478f53256b3a151c0d3c913213477ac858ba035ab27a941a8d0754f32f2dfc7
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %%
os.chdir('drive/My Drive/Colab Notebooks/practice')

# %%
titanic = pd.read_excel('./titanic.xlsx')
titanic
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
titanic.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass  ...        Fare    Cabin  Embarked
# count    891.000000  891.000000  891.000000  ...  891.000000      204       889
# unique          NaN         NaN         NaN  ...         NaN      147         3
# top             NaN         NaN         NaN  ...         NaN  B96 B98         S
# freq            NaN         NaN         NaN  ...         NaN        4       644
# mean     446.000000    0.383838    2.308642  ...   32.204208      NaN       NaN
# std      257.353842    0.486592    0.836071  ...   49.693429      NaN       NaN
# min        1.000000    0.000000    1.000000  ...    0.000000      NaN       NaN
# 25%      223.500000    0.000000    2.000000  ...    7.910400      NaN       NaN
# 50%      446.000000    0.000000    3.000000  ...   14.454200      NaN       NaN
# 75%      668.500000    1.000000    3.000000  ...   31.000000      NaN       NaN
# max      891.000000    1.000000    3.000000  ...  512.329200      NaN       NaN
#
# ...

# %% [markdown]
# ##finding and dropping DUPLICATED VALUES

# %%
titanic['Name'].duplicated(False)

#there is no duplicated NAMES
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
titanic['Name'].drop_duplicates(keep = 'first')
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ##NA - fill, drop, replace

# %%
#fill NA - AGE by mean value

titanic['Age'] = titanic['Age'].fillna(titanic['Age'].mean())

# %%
#cabin null values should be replaced

# %% [markdown]
# ##여기부터 다시 해야함!!!

# %%
#drop NA - Embarked
#only 2 values are missing, so I just dropped 2 rows

titanic['Embarked'] = titanic['Embarked'].dropna(axis = 0)

# %%
titanic['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# ##INFO, ISNULL,  VALUE COUNTS

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
